# %% [markdown]
# # Basic UNIX
#
# ## What is UNIX?
#
# UNIX is an **operating system** (analogous to DOS and Windows) which was first developed in the 1960s. By operating system, we mean the suite of programs which make the computer work. It is a stable, multi-user, multi-tasking system for servers, desktops and laptops.
#
# ## The UNIX operating system
#
# UNIX itself is historical, but it has spawned many different modern operating systems, such as Linux (Fedora, Suse, Arch, Red Star Linux…and Ubuntu) and Berkeley Software Distribution (BSD).
#
# Contrary to Windows and MAC OS X, UNIX-based systems do not rely on a graphical interface.
#
# - With UNIX, you don’t use the mouse!
# - With Linux, you often do ~ Graphical user interface (GUI) is integrated
# - But advanced use often requires a text-only interface
#
#
# The UNIX operating system is made up of three parts: the **kernel**, the **shell** and the **programs**.

# %% [markdown]
# ![kernel.png](data:image/png;base64,...)

# %% [markdown]
# As an illustration of the way that the shell and the kernel work together, suppose a user types **rm myfile** (which has the effect of removing the file myfile). The shell searches the filestore for the file containing the program **rm**, and then requests the kernel, through system calls, to execute the program **rm** on myfile.
#
# When the process rm myfile has finished running, the shell then returns the UNIX prompt `%` to the user, indicating that it is waiting for further commands.

# %% [markdown]
# ![shell.png](data:image/png;base64,...)

# %% [markdown]
# ### Text-only, you say?
#
# - It is now forgotten, but all historical computers ran on text-only interfaces (MS-DOS before Windows, OS/2 before Mac OS)
# - They are really useful for file and data manipulation
# - On Windows, we use emulators (which imitate UNIX behaviour) and remote access programs (which connect to real UNIX systems)
# - Every action has to be typed on the screen and sent to the system by hitting **ENTER**.
# - You are always in a directory, every command you send will affect the current directory unless stated otherwise
# - When you send a command, the system will look it up
#   - If it is a system command, it will execute it itself
#   - If not, it will look if it’s a third-party program installed on the computer
#   - If not, it will yell at you.
#
# ### The “frightening black screen with weird text on it”

# %% [markdown]
# ![weirdtext.PNG](data:image/png;base64,...)

# %% [markdown]
# ### The command prompt

# %% [markdown]
# ![username.PNG](data:image/png;base64,...)

# %% [markdown]
# ## Using the command-line
#
# - You have to remember all the useful commands (or look them up on the internet)
# - When you are not sure of the exact name of a command,
# 	 - `apropos keyword` (will give you the commands with keyword in their manual page header)
# 	 - `apropos copy`
#
# - You have to remember all the arguments for every command
#   - If you remember the name you can get help about the arguments
#   - Most commands have a “help me” argument
#     - `cp –-help`
#     - `wc --h`
# - There is a command that tells you how to run other commands:
#   - `man cp`

# %% [markdown]
# ### The shell has certain features to help the user inputting commands.
#    1. Filename Completion

# %% [markdown]
# ![tab.PNG](data:image/png;base64,...)

# %% [markdown]
#  2. History

# %% [markdown]
# ![history.PNG](data:image/png;base64,...)

# %% [markdown]
# ## The Directory Structure

# %% [markdown]
# ![dir.png](data:image/png;base64,...)

# %% [markdown]
# If you are user "its" you will land here:
#
# ```
# /home/its/
# ```
#
# or
#
# ```
# ~/
# ```

# %%
# Let us set up the connection with Google Drive.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Import some libraries that will make our life easier

# %%
# !pip install rpy2==3.1.0
import os # python related package to list files in the defined directory
import rpy2.ipython # allows to execute R if necessary from a python notebook
# %load_ext rpy2.ipython

# %%
# define home directory in python
os.chdir('/content/drive/My Drive/Complex_Traits/1a_Workshop_Basic_UNIX/home/')

# %%
# %%R
# # define home directory in R
# home_dir = '/content/drive/My Drive/Complex_Traits/1a_Workshop_Basic_UNIX/home/'
# setwd(paste0(home_dir))

# %% [markdown]
# Based on the directory structure described, the full path to the file report.doc is located here
#
# ```
# /home/its/ug1/ee51vn/report.doc
# ```

# %% [markdown]
# ## Commands part 1

# %% [markdown]
# ### Pathnames
# Pathnames enable you to work out where you are in relation to the whole file-system

# %%
# %%bash
#
# pwd #prints the working directory we defined earier
#
# # tip: if you set up previously the home directory correctly, you should be landed here:
# # /content/drive/MyDrive/Complex_Traits/1a_Workshop_Basic_UNIX/home

# %% [markdown]
# ### Making Directories
# ```
# mkdir <dir name>
# ```

# %%
# %%bash
#
# mkdir beta # example: we create a directory named "beta"

# %% [markdown]
# ### List directory content

# %% [markdown]
# we can use `ls` to se the content of the current directory and `pwd` to print the complete path we are at the moment

# %%
# %%bash
# ls
# pwd
# Out:
# beta
# compare.txt
# its
# wildcards
# /content/drive/.shortcut-targets-by-id/16-Fgp37znphoc5tnS-iUmbsa5x3HUS6l/Complex_Traits/1a_Workshop_Basic_UNIX/home

# %% [markdown]
# ### Changing to a different directory

# %% [markdown]
# ```
# cd <dir name>
# cd .. (The parent directory)
# . (The current directory)
# ```

# %%
# example: we move into the beta directory 
# %cd beta

# %%
# %%bash
#
# pwd # double-check that you're indeed in /content/drive/MyDrive/Complex_Traits/1a_Workshop_Basic_UNIX/home/beta

# %% [markdown]
# An Example:

# %% [markdown]
# > you are in this directory:
#
#  `/content/drive/My Drive/Complex_Traits/1a_Workshop_Basic_UNIX/home/beta/`
#
#  > and want to go to
#
# ` /content/drive/My Drive/Complex_Traits/1a_Workshop_Basic_UNIX/`
#
# > (this means, two folders closer to the starting point)

# %%
# %cd ../..
# Out:
# /content/drive/.shortcut-targets-by-id/16-Fgp37znphoc5tnS-iUmbsa5x3HUS6l/Complex_Traits/1a_Workshop_Basic_UNIX

# %% [markdown]
# ### Hands on part 1!!
#
# Based on the following picture do the following tasks:
#
# 1. Use `ls` to see the current directory
# 2. Use `cd` to go into the `ee51vn` folder
# 3. While in `ee51vn` folder, use `mkdir` to create a directory called `backups`
# 4. Try to freely explore the file system

# %% [markdown]
# ![dir.png](data:image/png;base64,...)

# %%
# %%bash
#
# # use this tab for task 1

# %%
# %%bash
#
# # use this tab for task 2

# %%
# %%bash
#
# # use this tab for task 3

# %%
# %%bash
#
# # use this tab to play around (4)

# %%
#@title answer 1
# !ls

# %%
#@title answer 2
# %cd '/content/drive/My Drive/Complex_Traits/1a_Workshop_Basic_UNIX/home/its/ug1/ee51vn/'

# %%
#@title answer 3
# !mkdir backups

# %% [markdown]
# ### Summary

# %% [markdown]
# ![Comm1.PNG](data:image/png;base64,...)

# %% [markdown]
# ## Commands part 2

# %% [markdown]
# There are two different commands to create a file in the Linux system which is as follows:
#
# - **`cat` command**: It is used to create the file with content.
# - **`touch` command**: It is used to create a file without any content. The file created using touch command is empty.

# %% [markdown]
# Creating a file in your google drive home directory

# %%
# first lets make sure that we are at home directory

# %cd /content/drive/My Drive/Complex_Traits/1a_Workshop_Basic_UNIX/home/
# Out:
# /content/drive/.shortcut-targets-by-id/16-Fgp37znphoc5tnS-iUmbsa5x3HUS6l/Complex_Traits/1a_Workshop_Basic_UNIX/home

# %%
# %%bash
#
# # secondly we want to create two files, the sample_file.txt and the sample_file_for_deletion.txt
#
# touch "/content/drive/My Drive/Complex_Traits/1a_Workshop_Basic_UNIX/home/sample_file.txt"
# touch "/content/drive/My Drive/Complex_Traits/1a_Workshop_Basic_UNIX/home/sample_file_for_deletion.txt"

# %% [markdown]
# see that those files have been successfully created

# %%
# %%bash
# pwd # see current directory
# ls # list content
# Out:
# /content/drive/.shortcut-targets-by-id/16-Fgp37znphoc5tnS-iUmbsa5x3HUS6l/Complex_Traits/1a_Workshop_Basic_UNIX/home/its/ug1/ee51vn
# backups
# report.txt.docx

# %% [markdown]
# ### Removing files
#
# To remove a specific file, you can use the command `rm` followed by the name of the file you want to remove
#
# ```
# rm filename
# ```
#
# If you are not in the directory where the file you want to remove is located, you can also define the path followed by the file name. For example:
#
# ```
# rm <dir_path>/<file1> (deletes file1 locaed in dir_path)
# ```

# %%
# %%bash
# # lets try to remove the "sample_file_for_deletion.txt" we just created
# rm sample_file_for_deletion.txt
# ls
# Out:
# backups
# report.txt.docx
# rm: cannot remove 'sample_file_for_deletion.txt': No such file or directory

# %% [markdown]
# ### Removing directories
#
# In Linux, you can remove/delete directories with the `rmdir` and `rm`.
#
# > `rmdir` is a command-line utility for deleting empty directories
#
# > `rm -r` you can remove directories and their contents recursively (not recommened for beginners).
#
#
# ```
# rmdir <dir_path>/<dir1> (deletes dir1 located in dir_path)
# ```

# %%
# lets try to remove the backup folder we created earlier located in:
# %cd /content/drive/My Drive/Complex_Traits/1a_Workshop_Basic_UNIX/home/its/ug1/ee51vn/

# !ls

# %%
# %%bash
#
# rmdir backups
# ls
# Out:
# report.txt.docx

# %% [markdown]
# ### Moving and renaming files
#
# To move a file in a linux, you use the `mv` command to move a file from one location to another.
#
# > Tip: As long as you know where you want to take a file from and where you want to move it to, you can send files from any location to any location, no matter where you are
#
#
# ```
# mv  <file1> <dir1> (moves file1 to dir1)
# ```
#
# `mv` command can be also used for renaming files and directories. We need to give *`SOURCE`* file to *`DESTINATION`* file using the following `mv` command syntax:
#
# ```
# mv <file1> <file2> (renames file1 to file2)
#
# ```
# The same logic applies to cases such as:
#
# ```
# mv oldname newname
# mv SOURCE DEST
# mv olddir newdir
# mv old-file new-file
# ```

# %%
# %%bash
# ## an example on renaming
# pwd
# Out:
# /content/drive/.shortcut-targets-by-id/16-Fgp37znphoc5tnS-iUmbsa5x3HUS6l/Complex_Traits/1a_Workshop_Basic_UNIX/home/its/ug1/ee51vn

# %%
# %cd /content/drive/MyDrive/Complex_Traits/1a_Workshop_Basic_UNIX/home/
# Out:
# /content/drive/.shortcut-targets-by-id/16-Fgp37znphoc5tnS-iUmbsa5x3HUS6l/Complex_Traits/1a_Workshop_Basic_UNIX/home

# %%
# !pwd
# Out:
# /content/drive/.shortcut-targets-by-id/16-Fgp37znphoc5tnS-iUmbsa5x3HUS6l/Complex_Traits/1a_Workshop_Basic_UNIX/home

# %%
# !ls
# Out:
# beta  compare.txt  its	sample_file.txt  wildcards

# %%
# %%bash
# # an example on renaming:
# mv sample_file.txt sample_file_renamed.txt

# %%
# !ls
# Out:
# beta  compare.txt  its	sample_file_renamed.txt  wildcards

# %% [markdown]
# ### Copying files
#
# To copy files and directories use the `cp` command. For example the following command make a copy of file 1 in the current directory and calls it file 2:
#
# `cp <file1> <file2>`

# %%
# %%bash
# # an example: we copy the sample_file_renamed.txt to beta folder
# cp sample_file_renamed.txt beta

# %%
# %%bash
# # see the filed is copied in beta directory
# ls beta
# Out:
# sample_file_renamed.txt

# %% [markdown]
# ### Searching any keywork on a file
#
# `grep` looks for text within files. It follows this order:
# ```
# grep keyword <file>
# ```
#
# For example to find `this_word` in `file.txt`:
#
# ```
# grep this_word file.txt
# ```

# %% [markdown]
# ### Count how many lines a file has
#
# There are several ways to count lines in a file. `wc` (*word count*) is the easiest and widely used.
#
# > The `wc` utility displays the number of lines, words, and bytes contained in each input file.
#
# The syntax is:
#
# ```
# wc -l <file>
# ```

# %% [markdown]
# ### Other utilities
#
# - `cat <file>` (displays the contents of a file on the screen)
#
# - `head <file>` (writes the first ten lines of a file to the screen)
#
# - `tail <file>` (writes the last ten lines of a file to the screen)
#
# ### Other Useful utilities for your local terminal (but not colabs)
#
#
# - `pico` or `nano` `<filename>` followed up by `ctrl+x` to exit, answering `Y` if you want to save the changes and enter
#
# - `cat>filename` followed up by `ctrl+d` to save and exit
#
# - `clear` (clears screen)
#
# - `less <file>` (writes the contents of a file onto the screen a page at a time)

# %% [markdown]
# ### Hands-On part 2!!!

# %% [markdown]
# 1. Create a `.txt` file.
# 2. Create a backup of your `.txt` file by copying it to a file called `science.bak.`
# 3. Delete `science.bak.`
# 4. Rename your `.txt` file to `VSS.txt.`
# 5. Create a directory called `tempstuff`, then remove it.
# 6. Place a copy of `/content/drive/MyDrive/Complex_Traits/1a_Workshop_Basic_UNIX/home/compare.txt` to `/content/drive/My Drive/Complex_Traits/1a_Workshop_Basic_UNIX/home/its/ug1/ee51vn/` and rename it as `comp.txt`.
# 7. Display the contents of `comp.txt` on the screen and try to find `‘998935’`.

# %%
# %%bash
#
# # use this tab to solve task1

# %%
# %%bash
#
# # use this tab to solve task2

# %%
# %%bash
#
# # use this tab to solve task3

# %%
# %%bash
#
# # use this tab to solve task4

# %%
# %%bash
#
# # use this tab to solve task5

# %%
# %%bash
#
# # use this tab to solve task6

# %%
# use this tab to solve task7
# Tip: use %cd  to move into the directory and !grep for searching

# %%
#@title Solutions
# %%bash

# In order to make this cell work, you have to execute each answer in a seperate cell


    ################################################
    ################ Solutions #####################
    ################################################


# 1 Create a .txt file.
touch "/content/drive/My Drive/Complex_Traits/1a_Workshop_Basic_UNIX/home/.txt"

# 2 Create a backup of your .txt file by copying it to a file called science.bak.
cp .txt science.bak.

# 3 Delete science.bak.
rm science.bak.

# 4 Rename your .txt file to VSS.txt.
mv .txt VSS.txt

# 5 Create a directory called tempstuff, then remove it
mkdir tempstuff
rmdir tempstuff

# 6 Place a copy of /content/drive/MyDrive/Complex_Traits/1a_Workshop_Basic_UNIX/home/compare.txt 
# to /content/drive/My Drive/Complex_Traits/1a_Workshop_Basic_UNIX/home/its/ug1/ee51vn/ 
cp compare.txt '/content/drive/My Drive/Complex_Traits/1a_Workshop_Basic_UNIX/home/its/ug1/ee51vn/'

# rename it as comp.txt
mv '/content/drive/My Drive/Complex_Traits/1a_Workshop_Basic_UNIX/home/its/ug1/ee51vn/compare.txt' '/content/drive/My Drive/Complex_Traits/1a_Workshop_Basic_UNIX/home/its/ug1/ee51vn/comp.txt'


# 7 Display the contents of comp.txt on the screen and try to find ‘998935’.
cd "/content/drive/My Drive/Complex_Traits/1a_Workshop_Basic_UNIX/home/its/ug1/ee51vn/"
grep 998935 comp.txt

# %% [markdown]
# ### Summary

# %% [markdown]
# ![Comm2.PNG](data:image/png;base64,...)

# %% [markdown]
# ## Commands part 3

# %% [markdown]
# ### The `*` Wildcard
#
# Bash Wildcards is the unofficial term for the Bash Pattern Matching characters. It helps simplifing long and complex command lines.
#
# - In order to list all files in the current directory starting with list....
#
#   ```
# ls list*
# ```
#
# - In order to list all files in the current directory ending with `.txt`
#
#   ```
# ls *.txt
# ```
#
# - In order to list all files in the current directory containing the string `body` at any possible place
#
#   ```
# ls *body*
# ```

# %% [markdown]
# ### Compress/Expand a zip file format
#
# - To compress the file `filename.txt` in `zip` format, we use the command `gzip` as follows
#
#   ```
# gzip filename.txt
# ```
#
# - To expand a `zip` file we use the command `gunzip` as follows
#
#   ```
#   gunzip filename.txt.gz
# ```

# %% [markdown]
# ### Hands-On part 3!!!

# %% [markdown]
# 1. Go to the folder named `wildcards` `'/content/drive/My Drive/Complex_Traits/1a_Workshop_Basic_UNIX/home/wildcards'`
#
# 2. Use the wildcard argument `*` to list all files containing the string `results`. How many files your command returns?
#
# 3. Rename the files `interaction.error.txt` `interaction.error2.txt` to `error1.txt` and `error2.txt`, make a folder `errors` and copy them in that directory
#
# 4. Compress and expand file `interaction.chromosome20.txt` located in the `wildcard` folder

# %%
# %%bash
#
# # use this tab to solve task 1

# %%
# %%bash
#
# # use this tab to solve task 2

# %%
# %%bash
#
# # use this tab to solve task 3

# %%
# %%bash
#
# # use this tab to solve task 4

# %%
#@title answer1
# %cd /content/drive/My Drive/Complex_Traits/1a_Workshop_Basic_UNIX/home/wildcards
# !pwd

# %%
#@title answer2
# %%bash
ls *results*

# %%
#@title answer 3

# %%bash

mv interaction.error.txt error1.txt 
mv interaction.error2.txt error2.txt

mkdir errors
mv error1.txt error2.txt errors

# %%
#@title Answer 4
# %%bash
# gzip interaction.chromosome20.txt
# gunzip interaction.chromosome20.txt

# %% [markdown]
# ## File system security and 𝐎𝐰𝐧𝐞𝐫𝐬𝐡𝐢𝐩
#
# - Owner: the owner is the user who created the file or directory
#
# - Group: a group can have multiple users. All users in the group have the same permissions to access the file or directory
#
# - Other: other means those who are not owners or members of the group
#
# - `ls –l`

# %% [markdown]
# ![Security.png](data:image/png;base64,...)

# %% [markdown]
# ![permission.png](data:image/png;base64,...)
